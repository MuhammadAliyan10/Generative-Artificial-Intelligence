# %%
name:str = ["Aliyan","Noor","Usama"]

# %%
print(name)
# Out:
# ['Aliyan', 'Noor', 'Usama']

# %%
print(len(name))
# Out:
# 3

# %%
la:list[str] = list(("aliyan", "Noor", "Usama"))
print(la)
# Out:
# ['aliyan', 'Noor', 'Usama']

# %%
print(name[0:2])
# Out:
# ['Aliyan', 'Noor']

# %%
if "Aliyan" in name:
    print("Yes") 
else:
    print("No")
# Out:
# Yes

# %%
name[0] = "Muhammad Aliyan"

# %%
print(name)
# Out:
# ['Muhammad Aliyan', 'Noor', 'Usama']

# %%
name.insert(1,"Muhammad Noman")

# %%
print(name)
# Out:
# ['Aliyan', 'Muhammad Noman', 'Noor', 'Usama']

# %%
name.append("Zubair")

# %%
print(name)
# Out:
# ['Aliyan', 'Muhammad Noman', 'Noor', 'Usama', 'Zubair']

# %%
[print(x) for x in name]
# Out:
# Aliyan
# Muhammad Noman
# Noor
# Usama
# Zubair
# [None, None, None, None, None]

# %%
f : list[str]= ['apple','chery','banana','mango']
g : list[str]= [x for x in f if x =="apple"]
print(g)
# Out:
# ['apple']
